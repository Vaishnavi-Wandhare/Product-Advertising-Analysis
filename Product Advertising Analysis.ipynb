# %% [markdown]
# ## <p style="padding:7px;background-color:gold;margin:10;color:teal;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:600"> 💹🛍️🏪🎯  Product Advertising Analysis  🎯🏪🛍️💹</p>

# %% [markdown]
# # 🎯Business Problem Understanding

# %% [markdown]
# Explore the different advertising channels and the resulting product sales. Aim to investigate the impact of advertising on sales.
# Interpret the result of the analysis to extract actionable insights for decision-making. This may involve identifying which advertising channels contribute most to sales, understanding the dyamics of advertising effectiveness over time.
#
# Based on the findings, provide recommendations for optimizing advertising strategies to maximize sales impact. This could include reallocating budget towards more effective channels, adjusting the timing or frequency of advertising campaigns, or exploring innovative approaches to reach target audiences more effectively.

# %% [markdown]
# #### ⚒️<u> Importing Required Python Libraries </u>

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 🎯Data Understanding

# %% [markdown]
# #### 🌟<u> Check and import dataset </u>

# %%
Adv_df = pd.read_csv("C:\\Users\\HP\\Downloads\\Datasets\\Advertising_Data.csv")
Adv_df
# Out:
#          TV  Billboards  Google_Ads  Social_Media  Influencer_Marketing  \
# 0    281.42      538.80      123.94        349.30                242.77
# 1    702.97      296.53      558.13        180.55                781.06
# 2    313.14      295.94      642.96        505.71                438.91
# 3    898.52       61.27      548.73        240.93                278.96
# 4    766.52      550.72      651.91        666.33                396.33
# ..      ...         ...         ...           ...                   ...
# 295  770.05      501.36      694.60        172.26                572.26
# 296  512.38      250.83      373.78        366.95                987.14
# 297  998.10      858.75      781.06         60.61                174.63
# 298  322.35      681.22      640.29        343.65                534.22
# 299  476.45      884.77      301.79        802.30                434.82
#
#      Affiliate_Marketing  Product_Sold
# 0                 910.10        7164.0
# ...

# %% [markdown]
# #### 🌟<u> Data Understanding </u>

# %%
Adv_df.columns
# Out:
# Index(['TV', 'Billboards', 'Google_Ads', 'Social_Media',
#        'Influencer_Marketing', 'Affiliate_Marketing', 'Product_Sold'],
#       dtype='object')

# %% [markdown]
# #### 📌<u> Explore Dataframe </u>

# %%
Adv_df.head()
# Out:
#        TV  Billboards  Google_Ads  Social_Media  Influencer_Marketing  \
# 0  281.42      538.80      123.94        349.30                242.77
# 1  702.97      296.53      558.13        180.55                781.06
# 2  313.14      295.94      642.96        505.71                438.91
# 3  898.52       61.27      548.73        240.93                278.96
# 4  766.52      550.72      651.91        666.33                396.33
#
#    Affiliate_Marketing  Product_Sold
# 0               910.10        7164.0
# 1               132.43        5055.0
# 2               464.23        6154.0
# 3               432.27        5480.0
# 4               841.93        9669.0

# %%
Adv_df.describe
# Out:
# <bound method NDFrame.describe of          TV  Billboards  Google_Ads  Social_Media  Influencer_Marketing  \
# 0    281.42      538.80      123.94        349.30                242.77
# 1    702.97      296.53      558.13        180.55                781.06
# 2    313.14      295.94      642.96        505.71                438.91
# 3    898.52       61.27      548.73        240.93                278.96
# 4    766.52      550.72      651.91        666.33                396.33
# ..      ...         ...         ...           ...                   ...
# 295  770.05      501.36      694.60        172.26                572.26
# 296  512.38      250.83      373.78        366.95                987.14
# 297  998.10      858.75      781.06         60.61                174.63
# 298  322.35      681.22      640.29        343.65                534.22
# 299  476.45      884.77      301.79        802.30                434.82
#
#      Affiliate_Marketing  Product_Sold
# ...

# %%
Adv_df.shape
# Out:
# (300, 7)

# %%
Adv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TV                    300 non-null    float64
#  1   Billboards            300 non-null    float64
#  2   Google_Ads            300 non-null    float64
#  3   Social_Media          300 non-null    float64
#  4   Influencer_Marketing  300 non-null    float64
#  5   Affiliate_Marketing   300 non-null    float64
#  6   Product_Sold          300 non-null    float64
# dtypes: float64(7)
# memory usage: 16.5 KB

# %%
Adv_df.describe().T.round(2).style.background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_46bc2_row0_col0, #T_46bc2_row0_col3, #T_46bc2_row0_col7, #T_46bc2_row1_col0, #T_46bc2_row1_col2, #T_46bc2_row1_col3, #T_46bc2_row1_col7, #T_46bc2_row2_col0, #T_46bc2_row2_col7, #T_46bc2_row3_col0, #T_46bc2_row3_col1, #T_46bc2_row3_col2, #T_46bc2_row3_col6, #T_46bc2_row3_col7, #T_46bc2_row4_col0, #T_46bc2_row4_col1, #T_46bc2_row4_col3, #T_46bc2_row4_col4, #T_46bc2_row4_col6, #T_46bc2_row4_col7, #T_46bc2_row5_col0, #T_46bc2_row5_col1, #T_46bc2_row5_col2, #T_46bc2_row5_col3, #T_46bc2_row5_col5, #T_46bc2_row5_col6, #T_46bc2_row5_col7, #T_46bc2_row6_col0 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_46bc2_row0_col1, #T_46bc2_row0_col2, #T_46bc2_row0_col4, #T_46bc2_row0_col5, #T_46bc2_row0_col6, #T_46bc2_row1_col4, #T_46bc2_row2_col2, #T_46bc2_row2_col6, #T_46bc2_row3_col4, #T_46bc2_row4_col2, #T_46bc2_row5_col4 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# ...

# %% [markdown]
# # 🎯Data Preparation

# %% [markdown]
# #### ⭐ <u> Data Cleaning </u>

# %% [markdown]
# ##### 📌 Checking missing / null values

# %%
Adv_df.isnull().sum()
# Out:
# TV                      0
# Billboards              0
# Google_Ads              0
# Social_Media            0
# Influencer_Marketing    0
# Affiliate_Marketing     0
# Product_Sold            0
# dtype: int64

# %% [markdown]
# 🔍 **In Advertising Data set there is no missing value.**

# %% [markdown]
# ####  📌Check for duplicates

# %%
Adv_df_dups = Adv_df[Adv_df.duplicated()]
Adv_df_dups
# Out:
# Empty DataFrame
# Columns: [TV, Billboards, Google_Ads, Social_Media, Influencer_Marketing, Affiliate_Marketing, Product_Sold]
# Index: []

# %% [markdown]
# ###  🌟 <u> Exploratory Data Analysis (EDA)</u>

# %% [markdown]
# #### 📌 Analysis and Correlation

# %%
Adv_df.corr().T.round(2).style.background_gradient(cmap='mako_r')
# Out:
# <style type="text/css">
# #T_e7f1e_row0_col0, #T_e7f1e_row1_col1, #T_e7f1e_row2_col2, #T_e7f1e_row3_col3, #T_e7f1e_row4_col4, #T_e7f1e_row5_col5, #T_e7f1e_row6_col6 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# #T_e7f1e_row0_col1, #T_e7f1e_row1_col0, #T_e7f1e_row5_col4 {
#   background-color: #daf3e1;
#   color: #000000;
# }
# #T_e7f1e_row0_col2 {
#   background-color: #8bdab2;
#   color: #000000;
# }
# #T_e7f1e_row0_col3, #T_e7f1e_row2_col4, #T_e7f1e_row2_col5, #T_e7f1e_row3_col0, #T_e7f1e_row4_col3, #T_e7f1e_row4_col6, #T_e7f1e_row5_col1, #T_e7f1e_row5_col2 {
#   background-color: #def5e5;
#   color: #000000;
# }
# #T_e7f1e_row0_col4 {
#   background-color: #bee8ca;
#   color: #000000;
# }
# #T_e7f1e_row0_col5 {
#   background-color: #65d0ad;
#   color: #000000;
# }
# #T_e7f1e_row0_col6 {
#   background-color: #45bdad;
#   color: #f1f1f1;
# }
# #T_e7f1e_row1_col2 {
#   background-color: #7fd7af;
#   color: #000000;
# }
# ...

# %% [markdown]
# ⭕ **The heatmap visualizes the correlation coefficients between variables.**

# %%
sns.heatmap(Adv_df.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot((Adv_df),hue='Product_Sold')

# %% [markdown]
# #### 🔸 Histogram of Advertising Costs vs Products Sold

# %%
Adv_df.hist(bins=30, figsize=(15,10),color='turquoise')
plt.suptitle("Distribution of Advertising Costs and Products Sold")
plt.show()

# %% [markdown]
# 🔍 **Each Scatter plot shows the relationship between the spending of a given advertising channel and the corresponding number of products sold.**

# %%
sns.regplot(x = "Product_Sold", y = "Affiliate_Marketing",color='deeppink', data = Adv_df)
# Out:
# <Axes: xlabel='Product_Sold', ylabel='Affiliate_Marketing'>

# %%
sns.regplot(x = "Product_Sold", y = "Billboards",color='darkred', data = Adv_df)
# Out:
# <Axes: xlabel='Product_Sold', ylabel='Billboards'>

# %%
sns.regplot(x = "Product_Sold", y = "Social_Media",color='orange', data = Adv_df)
# Out:
# <Axes: xlabel='Product_Sold', ylabel='Social_Media'>

# %%
sns.regplot(x = "Product_Sold", y = "Influencer_Marketing",color='mediumslateblue', data = Adv_df)
# Out:
# <Axes: xlabel='Product_Sold', ylabel='Influencer_Marketing'>

# %%
sns.regplot(x = "Product_Sold", y = "TV",color='darkturquoise', data = Adv_df)
# Out:
# <Axes: xlabel='Product_Sold', ylabel='TV'>

# %% [markdown]
# # 🔍📊🔭Insights
#
# ### 🥨The visualizations provide further insights into the findings:
#
# #### 🔸Scatter Plots - Advertising Channels vs. Products Sold
# Each plot shows the relationship between the spending of a given advertising channel and the corresponding number of products sold. Generally, the more that is spent on advertising, the more products are sold. Channels like Affiliate Marketing and Billboards produce the highest purchase amounts.
#
# #### 🔸Correlation Matrix Heatmap
# The heatmap visualizes the correlation coefficients between variables.
#
# Affiliate Marketing has the highest positive correlation with Product Sold, reinforcing its potential effectiveness in driving sales. This analysis suggests that advertising through channels such as Affiliate Marketing, Billboards, and Social Media are positiveley associated with sales. With these insights they can guide further marketing strategies.
